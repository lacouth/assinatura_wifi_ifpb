# %% [markdown]
# # **Conversor MAC to CRC32**
#
# ---
#
# Versão 1.0.0

# %% [markdown]
# ## **Importação das bibliotecas**

# %%
import binascii

# %% [markdown]
# ## **Definição da Função**

# %%
def mac_to_crc32(mac):
    return binascii.crc32(mac.encode()) & 0xFFFFFFFF

# %% [markdown]
# ## **Conversão**

# %%
print("\nArray CRC32 para ESP32:\n")
print("uint32_t macHashList[] = {")
for mac in macs:
    crc = mac_to_crc32(mac)
    print(f"  0x{crc:08X},")
print("};")
